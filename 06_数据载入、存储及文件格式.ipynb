# %%
import pandas as pd

# %% [markdown]
# ## 一、csv文件

# %% [markdown]
# ### （一）读

# %%
# 这里采用双斜杠\\原因是由于读取文件和python文件没有在同一个文件夹里，导致报错FileNotFoundError，需要使用绝对路径才可以
df_csv = pd.read_csv('.\\data_for_book\\chapter_06\\read_csv.csv')  
df_csv.head()
# 更多详细参数请参考官方文档或者《用python进行数据分析p170》
# Out:
#       贷款金额  贷款期限     利率  每月还款金额  贷款等级  工作年限  房屋所有权       年收入  收入是否由LC验证  \
# 0  18000.0     1   7.99  563.98     1   2.0      2   60000.0          3
# 1  13000.0     1   5.32  391.50     1  10.0      2  101800.0          3
# 2   5000.0     1  10.49  162.49     2  10.0      3   75000.0          3
# 3  11100.0     1   5.32  334.28     1   3.0      3   60000.0          3
# 4  25000.0     2  28.69  788.84     6  10.0      3   83807.4          1
#
#    target                贷款目的   月负债比  过去两年借款人逾期30天以上的数字  过去6个月内被查询次数  \
# 0       0  debt_consolidation  30.76                0.0            0
# 1       0         credit_card  18.91                0.0            0
# 2       0               other  11.01                0.0            1
# 3       0         credit_card  18.91                0.0            0
# 4       0  debt_consolidation  13.17                0.0            0
#
#    摧毁公共记录的数量  额度循环使用率  总贷款笔数  拖欠的逾期款项  留置税数量
# 0        0.0     17.8   22.0      0.0    0.0
# ...

# %%
# 不推荐
df_csv = pd.read_table('.\\data_for_book\\chapter_06\\read_csv.csv', sep=',')
df_csv.head()
# Out:
# D:\software\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#       贷款金额  贷款期限     利率  每月还款金额  贷款等级  工作年限  房屋所有权       年收入  收入是否由LC验证  \
# 0  18000.0     1   7.99  563.98     1   2.0      2   60000.0          3
# 1  13000.0     1   5.32  391.50     1  10.0      2  101800.0          3
# 2   5000.0     1  10.49  162.49     2  10.0      3   75000.0          3
# 3  11100.0     1   5.32  334.28     1   3.0      3   60000.0          3
# 4  25000.0     2  28.69  788.84     6  10.0      3   83807.4          1
#
#    target                贷款目的   月负债比  过去两年借款人逾期30天以上的数字  过去6个月内被查询次数  \
# 0       0  debt_consolidation  30.76                0.0            0
# 1       0         credit_card  18.91                0.0            0
# 2       0               other  11.01                0.0            1
# 3       0         credit_card  18.91                0.0            0
# ...

# %% [markdown]
# ### （二）写

# %%
df_csv = pd.read_csv('.\\data_for_book\\chapter_06\\read_csv.csv')  
df_csv.to_csv('.\\data_for_book\\chapter_06\\to_csv.csv', encoding='gbk')

# %% [markdown]
# ## 二、Excel文件

# %% [markdown]
# ### （一）读

# %%
df_excel = pd.read_excel('.\\data_for_book\\chapter_06\\read_excel.xlsx', sheet_name='Sheet1', encoding='gbk')
df_excel.head()
# Out:
#    Unnamed: 0   贷款金额  贷款期限     利率  每月还款金额  贷款等级  工作年限  房屋所有权       年收入  \
# 0           0  18000     1   7.99  563.98     1     2      2   60000.0
# 1           1  13000     1   5.32  391.50     1    10      2  101800.0
# 2           2   5000     1  10.49  162.49     2    10      3   75000.0
# 3           3  11100     1   5.32  334.28     1     3      3   60000.0
# 4           4  25000     2  28.69  788.84     6    10      3   83807.4
#
#    收入是否由LC验证  target                贷款目的   月负债比  过去两年借款人逾期30天以上的数字  \
# 0          3       0  debt_consolidation  30.76                  0
# 1          3       0         credit_card  18.91                  0
# 2          3       0               other  11.01                  0
# 3          3       0         credit_card  18.91                  0
# 4          1       0  debt_consolidation  13.17                  0
#
#    过去6个月内被查询次数  摧毁公共记录的数量  额度循环使用率  总贷款笔数  拖欠的逾期款项  留置税数量
# 0            0          0     17.8     22        0      0
# ...

# %% [markdown]
# ### （二）写

# %%
df_csv = pd.read_csv('.\\data_for_book\\chapter_06\\read_csv.csv')  
df_csv.to_excel('.\\data_for_book\\chapter_06\\to_excel.xlsx', encoding='gbk', sheet_name='to_excel')

# %% [markdown]
# ## 三、JSON文件

# %% [markdown]
# ### （一）读

# %%
df_json = pd.read_json('.\\data_for_book\\chapter_06\\read_json.json')
df_json.head()
# Out:
#        贷款金额  贷款期限     利率   每月还款金额  贷款等级  工作年限  房屋所有权       年收入  收入是否由LC验证  \
# 0     18000     1   7.99   563.98     1     2      2   60000.0          3
# 1     13000     1   5.32   391.50     1    10      2  101800.0          3
# 10    39000     1  15.99  1370.94     3    10      2   78000.0          1
# 100    6400     1  11.39   210.72     2     3      2  100000.0          1
# 1000   3000     1  13.49   101.80     3     8      2   80000.0          1
#
#       target                贷款目的   月负债比  过去两年借款人逾期30天以上的数字  过去6个月内被查询次数  \
# 0          0  debt_consolidation  30.76                  0            0
# 1          0         credit_card  18.91                  0            0
# 10         0  debt_consolidation  33.14                  0            0
# 100        0         credit_card   9.38                  1            3
# 1000       0      major_purchase   3.74                  0            0
#
#       摧毁公共记录的数量  额度循环使用率  总贷款笔数  拖欠的逾期款项  留置税数量
# ...

# %% [markdown]
# ### （二）写

# %%
df_csv.to_json('.\\data_for_book\\chapter_06\\to_json.json')

# %% [markdown]
# ## 四、html文件

# %% [markdown]
# ### （一）读

# %%
df_html = pd.read_html('.\\data_for_book\\chapter_06\\read_html.html', encoding='gbk')
df_html
# Out:
# [        Unnamed: 0     贷款金额  贷款期限     利率   每月还款金额  贷款等级  工作年限  房屋所有权  \
#  0                0  18000.0     1   7.99   563.98     1   2.0      2
#  1                1  13000.0     1   5.32   391.50     1  10.0      2
#  2                2   5000.0     1  10.49   162.49     2  10.0      3
#  3                3  11100.0     1   5.32   334.28     1   3.0      3
#  4                4  25000.0     2  28.69   788.84     6  10.0      3
#  5                5  25900.0     2  25.49   767.66     5  10.0      2
#  6                6   5000.0     1  11.44   164.74     2  10.0      3
#  7                7   6000.0     1   7.49   186.61     1   5.0      3
#  8                8  21500.0     1  11.39   707.86     2  10.0      2
#  9                9  10000.0     1  11.39   329.24     2   1.0      2
#  10              10  39000.0     1  15.99  1370.94     3  10.0      2
#  11              11   8000.0     1   7.99   250.66     1  10.0      2
# ...

# %% [markdown]
# ### （二）写

# %%
df_csv.to_html('.\\data_for_book\\chapter_06\\to_html.html')
